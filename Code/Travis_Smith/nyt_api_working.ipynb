# %%
! pip install nytimesarticle
! pip install yanytapi
# Out:
# Processing c:\users\travi\appdata\local\pip\cache\wheels\88\92\0f\d441bf1ccfcc3f98219f9d2f1c2277ccbe3521e35101f36229\nytimesarticle-0.1.0-cp37-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/fe/d3/4e4c59fd9b896571f2bd9564b78e79e8aef8f6c33c8b116ef88b12598c93/yanytapi-2.0.0-py2.py3-none-any.whl
# ...

# %%
from nytimesarticle import articleAPI
from yanytapi import SearchAPI
import pandas as pd
import requests
import sched, time
import time
# api = articleAPI('THFAgqFwEabG2AW7vxkxXQAEDXtZA4zK')
yourkey = ('THFAgqFwEabG2AW7vxkxXQAEDXtZA4zK')

# %%
# subject = 'SARS'
# body = 'World Health Organization'
# section_name = 'World'
# begin_date = 20030201
# end_date = 20030731

# def get_articles(date,query):
#     '''
#     This function accepts a year in string format (e.g.'1980')
#     and a query (e.g.'Amnesty International') and it will 
#     return a list of parsed articles (in dictionaries)
#     for that year.
#     '''
#     all_articles = []
#     for i in range(0,1): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
#         articles = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=SARS&fq=section_name:{section_name}
#         &begin_date={begin_date}
#         &end_date={end_date}
#         &page = str(i)
#         &api-key={yourkey}')
# #                page = str(i))
# #         articles = parse_articles(articles)
#         all_articles = all_articles + articles
#     return(all_articles)

# %%
# pulls the data from teh API

# keywords for the api call
subject = 'H1N1'
# body = 'World Health Organization'
type_of_material = ''
section_name = 'World'
begin_date = 20090315
end_date = 20100930
all_articles = pd.DataFrame()

# for loop running for the 100 pages in teh query
for i in range (0,50):

    articles = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={subject}&fq=section_name:{section_name}&begin_date={begin_date}&end_date={end_date}&page={i}&api-key={yourkey}')
#     articles = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=SARS&fq=section_name:{section_name}&begin_date={begin_date}&end_date={end_date}&page={i}&api-key={yourkey}')

#     parses the data from the pull and puts into a dataframe
    articles = pd.DataFrame({
                    'dates':[x['pub_date'] for x in articles.json()['response']['docs']],
                    'headline':[x['headline']['main'] for x in articles.json()['response']['docs']],
                    'section_name':[x['section_name'] for x in articles.json()['response']['docs']],
                    'abstract':[x['abstract'] for x in articles.json()['response']['docs']],
#                     'keywords':[x['keywords'] for x in articles.json()['response']['docs']],
#                     'print_page':[x['print_page'] for x in articles.json()['response']['docs']]
 
                            })
#     append API call to the articles dataframs
    all_articles = all_articles.append(articles)
    time.sleep(6)
all_articles
# Out:
#                       dates  \
# 0  2009-11-11T17:11:14+0000
# 1  2009-11-07T01:28:47+0000
# 2  2009-05-09T02:34:18+0000
# 3  2009-05-06T12:15:35+0000
# 4  2009-12-03T02:18:42+0000
# 5  2009-08-17T05:00:00+0000
# 6  2009-08-17T19:15:41+0000
# 7  2009-06-11T10:40:56+0000
# 8  2009-11-06T03:38:40+0000
# 9  2009-11-13T00:00:42+0000
# 0  2009-05-07T01:13:52+0000
# 1  2009-06-11T11:08:05+0000
# 2  2009-08-12T19:26:55+0000
# 3  2009-11-14T01:23:00+0000
# 4  2009-11-16T01:13:18+0000
# 5  2009-10-08T00:41:42+0000
# 6  2009-04-26T21:48:36+0000
# 7  2009-12-09T14:37:22+0000
# 8  2009-09-20T21:01:31+0000
# 9  2009-09-20T05:00:00+0000
# 0  2009-04-26T15:30:56+0000
# 1  2009-10-23T00:30:58+0000
# 2  2009-05-11T07:38:23+0000
# 3  2009-05-02T20:17:18+0000
# 4  2009-12-11T18:32:20+0000
# 5  2009-05-22T12:14:04+0000
# 6  2009-05-26T00:51:58+0000
# 7  2009-05-18T11:58:40+0000
# 8  2009-05-04T15:11:02+0000
# 9  2009-04-24T15:59:47+0000
# 0  2009-04-26T00:52:43+0000
# 1  2009-08-31T05:00:00+0000
# ...

# %%
# articles

# %%
# outputs to CSV
all_articles.to_csv(f'{subject}.csv')

# %%
# block works, don't touch
# pull data from NYT API
# pages = (0,100)
subject = 'SARS'
body = 'World Health Organization'
section_name = 'World'
begin_date = 20030201
end_date = 20030731
# articles = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=SARS&fq=body:{body}ANDsection_name:{section_name}&begin_date={begin_date}&end_date={end_date}&api-key={yourkey}')
articles = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=SARS&fq=section_name:{section_name}&begin_date={begin_date}&end_date={end_date}&api-key={yourkey}')

# %%
articles.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Huge rock concert is held in Toronto, Ontario, organized in part by government with goal of proving to world that SARS no longer poses threat to those wanting to visit; when World Health Orgn issued travel advisories for Toronto, it prompted massive cancellations of conventions, concerts and vacations; more than 430,000 people crush into stadium to hear Rolling Stones, Rush and AC/DC perform; photo (M)',
#     'web_url': 'https://www.nytimes.com/2003/07/31/world/toronto-turns-on-rock-to-drown-out-sars-fears.html',
#     'snippet': 'Huge rock concert is held in Toronto, Ontario, organized in part by government with goal of proving to world that SARS no longer poses threat to those wanting to visit; when World Health Orgn issued travel advisories for Toronto, it prompted massi...',
# ...

# %%
# articles2 = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=SARS&fq=type_of_material:"Front Page"&begin_date={begin_date}&end_date={end_date}&page=1&api-key={yourkey}')
articles2 = requests.get(f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=SARS&begin_date={begin_date}&end_date={end_date}&page=1&api-key={yourkey}')

# %%
# block works, don't touch
# import pandas as pd

pd.DataFrame({
    'dates':[x['pub_date'] for x in articles2.json()['response']['docs']],
    'headline':[x['headline']['main'] for x in articles2.json()['response']['docs']],
    'section_name':[x['section_name'] for x in articles2.json()['response']['docs']],
    'abstract':[x['abstract'] for x in articles2.json()['response']['docs']],
#     'keywords':[x['keywords'][i]['rank'] for x in articles2.json()['response']['docs']],
#     if x['print_page'] is not None:
#     while x < 10:
#         try: 
     'print_page':
        if:[x['print_page'] for x in articles2.json()['response']['docs']] is none:
            0
        else: [x['print_page'] for x in articles2.json()['response']['docs']]
#         except:
#             0
#     continue
    #     'abstract':[x['keywords'] for x in articles.json()['response']['docs']]
    
})
# Out:
#   File "<ipython-input-157-e3d4895dbb81>", line 14
#     if:[x['print_page'] for x in articles2.json()['response']['docs']] is none:
#      ^
# SyntaxError: invalid syntax

# %%
# articles2.to_csv("articles2.csv)
pd.DataFrame({
    'dates':[x['pub_date'] for x in articles2.json()['response']['docs']],
    'headline':[x['headline']['main'] for x in articles2.json()['response']['docs']],
    'section_name':[x['section_name'] for x in articles2.json()['response']['docs']],
    'abstract':[x['abstract'] for x in articles2.json()['response']['docs']],
})
# Out:
#                       dates  \
# 0  2003-07-02T05:00:00+0000
# 1  2003-07-22T05:00:00+0000
# 2  2003-06-24T05:00:00+0000
# 3  2003-06-26T05:00:00+0000
# 4  2003-07-15T05:00:00+0000
# 5  2003-06-25T05:00:00+0000
# 6  2003-07-13T05:00:00+0000
# 7  2003-07-13T05:00:00+0000
# 8  2003-06-21T05:00:00+0000
# 9  2003-07-06T05:00:00+0000
#
#                                             headline  section_name  \
# 0  SARS Under Control in Toronto, World Health Ag...        Health
# 1  World Business Briefing | Asia: Singapore: Air...  Business Day
# 2                  Behind the Mask, The Fear of SARS       Science
# 3        World Briefing | Asia: China: New Sars Case         World
# 4            An Era Ends, Many Missions Accomplished        Health
# 5   China Has Quelled SARS, World Health Agency Says         World
# 6  New Wing at German Historical Museum; Thames M...        Travel
# 7                         The Problem of Exotic Pets       Opinion
# ...

# %%
# articles = api.search(q="SARS")
articles2.json()['response']['docs'][0].keys()
# Out:
# dict_keys(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section', 'print_page', 'source', 'multimedia', 'headline', 'keywords', 'pub_date', 'document_type', 'news_desk', 'section_name', 'byline', 'type_of_material', '_id', 'word_count', 'uri'])

# %%
articles2.json()['response']['docs'][5]['print_page']
# Out:
# '8'

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)
    return(news)

# %%
parse_articles(articles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-4ad1c9c43b50> in <module>
# ----> 1 parse_articles(articles)
#
# <ipython-input-84-9a484be117fc> in parse_articles(articles)
#       5     '''
#       6     news = []
# ----> 7     for i in articles['response']['docs']:
#       8         dic = {}
#       9         dic['id'] = i['_id']
#
# TypeError: 'Response' object is not subscriptable

# %%
def get_articles(date,query):
    '''
    This function accepts a year in string format (e.g.'1980')
    and a query (e.g.'Amnesty International') and it will 
    return a list of parsed articles (in dictionaries)
    for that year.
    '''
    all_articles = []
    for i in range(0,100): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
        articles = api.search(q = query,
#                fq = {'source':['Reuters','AP', 'The New York Times']},
               begin_date = date + '0101',
               end_date = date + '1231',
               sort='oldest',
               page = str(i))
        articles = parse_articles(articles)
        all_articles = all_articles + articles
    return(all_articles)

# %%
get_articles('2003','SARS')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-3cfb2ccf9581> in <module>
# ----> 1 get_articles('2003','SARS')
#
# <ipython-input-70-5cc03812c9a3> in get_articles(date, query)
#      14                sort='oldest',
#      15                page = str(i))
# ---> 16         articles = parse_articles(articles)
#      17         all_articles = all_articles + articles
#      18     return(all_articles)
#
# <ipython-input-67-9a484be117fc> in parse_articles(articles)
#       5     '''
#       6     news = []
# ----> 7     for i in articles['response']['docs']:
#       8         dic = {}
#       9         dic['id'] = i['_id']
#
# KeyError: 'response'

# %%
Amnesty_all = []
for i in range(1980,2014):
    print 'Processing' + str(i) + '...'
    Amnesty_year =  get_articles(str(i),'Amnesty International')
    Amnesty_all = Amnesty_all + Amnesty_year
# Out:
#   File "<ipython-input-72-cb5ac759db38>", line 3
#     print 'Processing' + str(i) + '...'
#                      ^
# SyntaxError: invalid syntax

# %%
api.search?
# Out:
# Signature: api.search(response_format=None, key=None, **kwargs)
# Docstring:
# Calls the API and returns a dictionary of the search results
#
# :param response_format: the format that the API uses for its response,
#                         includes JSON (.json) and JSONP (.jsonp).
#                         Defaults to '.json'.
#
# :param key: a developer key. Defaults to key given when the articleAPI class was initialized.
# File:      c:\users\travi\anaconda3\lib\site-packages\nytimesarticle.py
# Type:      method

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-9688f1d24953> in <module>
# ----> 1 ArticleAPI
#
# NameError: name 'ArticleAPI' is not defined

# %%
articleAPI
# Out:
# nytimesarticle.articleAPI

# %%
import sched, time

# %%
sched.scheduler
# Out:
# Init signature:
# sched.scheduler(
#     timefunc=<built-in function monotonic>,
#     delayfunc=<built-in function sleep>,
# )
# Docstring:      <no docstring>
# Init docstring:
# Initialize a new instance, passing the time and delay
# functions
# File:           c:\users\travi\anaconda3\envs\vizenv\lib\sched.py
# Type:           type
# Subclasses:
